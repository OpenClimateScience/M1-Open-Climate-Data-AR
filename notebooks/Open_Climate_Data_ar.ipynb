# %% [markdown]
# <div dir="rtl">
# # M1.1 - مصادر بيانات المناخ
#
# *جزء من:* [**Open Climate Data**](https://github.com/OpenClimateScience/M1-Open-Climate-Data) | **الدرس السابق** | **الدرس التالي**
# </div>

# %% [markdown]
# <div dir="rtl">
# **المحتويات:**
#
# 1. [الطقس مقابل المناخ](#Weather-versus-Climate)
# 2. [مشاكل جمع بيانات المناخ](#Issues-with-climate-data-collection)
# 3. [أجهزة الاستشعار والمحطات الأرضية](#Sensors-and-ground-stations)
# 4. [استكمال بيانات المحطات](#Interpolating-station-data)
# </div>

# %% [markdown]
# <div dir="rtl">
# ## الطقس مقابل المناخ
#
# غالبًا ما نسمع كلمتي "الطقس" و"المناخ" تُستخدمان بالتبادل. للتوضيح:
#
# - **الطقس** يشير إلى الظروف الجوية الحالية، عادةً على مقاييس زمنية بالساعة أو اليوم. على سبيل المثال، الطقس "هذا المساء" قد يشمل معدل هطول الأمطار بالساعة أو متوسط درجة الحرارة. الطقس "أمس" قد يشمل كمية الأمطار اليومية الإجمالية، أو الحد الأقصى لدرجة الحرارة اليومية، أو عدد ساعات سطوع الشمس اليومية.
#
# - **المناخ** يشير إلى النمط السائد طويل الأمد للظروف الجوية. على سبيل المثال، تصف كمية الأمطار السنوية المتوسطة مقدار الأمطار التي يمكنك *توقعها عادةً* في السنة. وصف المناخ يعتمد دائمًا على فترة زمنية ثابتة، سواء تم تحديدها أم لا. عندما نتحدث عن متوسط درجة الحرارة الشهرية، على سبيل المثال، يجب أن يكون ذلك استنادًا إلى فترة مرجعية، مثل المتوسط على مدار السنوات 1950 إلى 2000.
#
# **ومع ذلك، في هذا المنهاج، غالبًا ما نستخدم مصطلح *"بيانات المناخ"* للإشارة إلى كلا النوعين من البيانات، لتبسيط الأمر.**
# </div>

# %% [markdown]
# <div dir="rtl">
# ## تباين المناخ في الأنظمة الزراعية
#
# يرتبط دوران الماء والطاقة في نظام المناخ الأرضي لأن الشمس تدفئ هواء وسطح الأرض، وتحفز التمثيل الضوئي، وتبخر المياه. لفهم تأثير المناخ على الزراعة، نود قياس المتغيرات المناخية التالية:
#
# - درجة حرارة الهواء
# - درجة حرارة السطح/التربة
# - الإشعاع الشمسي
# - كمية الهطول
# - التبخر والنتح
# - الرطوبة (أو عجز ضغط البخار)
# - رطوبة التربة
#
# في هذه الوحدة، سنناقش أجهزة استشعار ونماذج وكالة ناسا التي توفر هذا النوع من المعلومات على مستوى العالم.
# </div>

# %% [markdown]
# <div dir="rtl">
# ## مشاكل جمع بيانات المناخ
#
# **من الصعب الحصول على بيانات المناخ لكل جزء من العالم وفي كل وقت.**
#
# - لا يمكننا وضع محطة طقس في كل نقطة على الأرض. حتى أننا لا نعرف بالضبط مدى قرب محطات الطقس من بعضها البعض، فقد يختلف ذلك بناءً على التطبيقات المختلفة أو المناطق المختلفة من العالم.
#
# - وبالمثل، فإن محطات الطقس لها تغطية محدودة. يمكن أن تختلف درجة الحرارة والرطوبة، على سبيل المثال، على مسافات قصيرة تصل إلى بضعة أمتار. لذلك قد تمثل أي محطة طقس منطقة صغيرة فقط.
#
# - في بعض مناطق العالم، تعيق التلال أو الجبال أنظمة الرادار الجوية، مما يحد من تغطيتها.
#
# نظرًا للقيود المذكورة أعلاه وكذلك القيود الحسابية، فإن البيانات التي تنتجها نماذج الطقس لها دقة مكانية محدودة. أحيانًا، قد يصف النموذج درجة الحرارة أو سرعة الرياح لمنطقة أكبر بكثير من حقل مزارع أو حتى أكبر من بلدة أو مقاطعة إدارية.
# </div>

# %% [markdown]
# <div dir="rtl">
# ## أجهزة الاستشعار والمحطات الأرضية
#
# هناك العديد من مصادر بيانات الطقس المختلفة. بالإضافة إلى أجهزة الاستشعار المثبتة على محطات الطقس الأرضية، هناك العديد من أجهزة الاستشعار المحمولة جواً والأقمار الصناعية المدارية حول الأرض التي توفر بيانات في الوقت الفعلي عن حالة الطقس. **تأمل المصادر المختلفة لبيانات الطقس (والمناخ) في الشكل أدناه.**
#
# ![](./assets/M1_fig_weather_data_sources.jpg)
#
# *الصورة مستخدمة بإذن من المنظمة العالمية للأرصاد الجوية (WMO).*
# </div>

# %% [markdown]
# <div dir="rtl">
# ## استكمال بيانات المحطات
#
# من الممكن معرفة حالة الطقس في موقع يصعب الوصول إليه، شريطة وجود محطة أساسية قريبة. هناك العديد من المبادئ الفيزيائية التي يمكننا استخدامها لاستكمال بيانات الطقس في موقع استنادًا إلى موقع أو أكثر قريب حيث يتم مراقبة الطقس. **نعلم أن درجة حرارة الهواء تنخفض مع الارتفاع بمعدل معين بناءً على الرطوبة (تأمل الشكل أدناه).**
#
# كما نعلم أنه في التضاريس الجبلية، تكون بعض المناطق مظللة لفترات أطول من غيرها. يمكن أن يؤثر الغطاء النباتي على درجة الحرارة المحسوسة لأن النبات يقوم بتظليل الأرض وأيضًا لأنه، في الطقس البارد، يمكن أن يكون النبات نفسه مصدرًا صغيرًا للحرارة. هذه العوامل الفيزيائية وغيرها يمكن أن تساعدنا في استنتاج حالة الطقس في موقع غير مراقب باستخدام نموذج. قد يكون هذا النموذج بسيطًا إحصائيًا أو معقدًا فيزيائيًا.
#
# ![](./assets/M1_fig_temperature_lapse.png)
#
# *الصورة الأصلية مستخدمة بإذن من السيد جمال س. أقلي (آث سالم).*
# </div>

# %% [markdown]
# <div dir="rtl">
# ---
#
# #### بشكل عام، هناك طريقتان يمكننا من خلالهما إجراء توقعات حول الظروف المناخية عبر الزمن والمكان: النماذج الإحصائية والنماذج الفيزيائية. ولكن قبل أن نتحدث عن ذلك، دعونا نحصل على بعض الخبرة العملية مع مجموعات بيانات المناخ التابعة لناسا.
# </div>
